# %%
import pandas as pd
import requests
import io

url= 'https://raw.githubusercontent.com/slu-openGIS/MO_HEALTH_Covid_Tracking/master/data/county/county_full.csv?_sm_au_=iTVT4DZWZtNnt5PPHftsvK0JJcR7F'
download = requests.get(url).content

# Reading the downloaded content and turning it into a pandas dataframe

df = pd.read_csv(io.StringIO(download.decode('utf-8')))
df_county_tests = df[(df.state == "Missouri")]
# Printing out the first 5 rows of the dataframe

df_county_tests.head()
# Out:
#       report_date  geoid county     state  cases  case_rate  new_cases  \
# 66270  2020-01-24  29001  Adair  Missouri      0        0.0        0.0
# 66271  2020-01-25  29001  Adair  Missouri      0        0.0        0.0
# 66272  2020-01-26  29001  Adair  Missouri      0        0.0        0.0
# 66273  2020-01-27  29001  Adair  Missouri      0        0.0        0.0
# 66274  2020-01-28  29001  Adair  Missouri      0        0.0        0.0
#
#        case_avg  deaths  mortality_rate  new_deaths  deaths_avg  \
# 66270       0.0       0             0.0         0.0         0.0
# 66271       0.0       0             0.0         0.0         0.0
# 66272       0.0       0             0.0         0.0         0.0
# 66273       0.0       0             0.0         0.0         0.0
# 66274       0.0       0             0.0         0.0         0.0
#
#        case_fatality_rate
# 66270                 NaN
# 66271                 NaN
# 66272                 NaN
# 66273                 NaN
# 66274                 NaN
