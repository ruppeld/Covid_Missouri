# %%
# Libraries needed for the tutorial

import pandas as pd
import requests
import io
import json
from pandas import json_normalize


url ='https://services6.arcgis.com/Bd4MACzvEukoZ9mR/arcgis/rest/services/county_MOHSIS_map/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json'
response = requests.get(url).json()
#print(json.dumps(response, indent=4, sort_keys=True))
json_normalize(response, 'features')
# Out:
#      attributes.OBJECTID attributes.NAME attributes.NAME2  attributes.CASES  \
# 0                   1990           Adair            ADAIR               290
# 1                   1991          Andrew           ANDREW               172
# 2                   1992        Atchison         ATCHISON                41
# 3                   1993         Audrain          AUDRAIN               340
# 4                   1994           Barry            BARRY               406
# ..                   ...             ...              ...               ...
# 112                 2102           Worth            WORTH                18
# 113                 2103          Gentry           GENTRY               108
# 114                 2104          DeKalb           DEKALB                91
# 115                 2105          Maries           MARIES                57
# 116                 2106          Phelps           PHELPS               328
#
#      attributes.DEATHS  attributes.Shape__Area  attributes.Shape__Length  \
# 0                    0            1.473390e+09             155251.053818
# 1                    1            1.130287e+09             163786.567767
# 2                    0            1.418004e+09             188930.314765
# 3                    2            1.803689e+09             215719.629416
# 4                    5            2.047063e+09             183363.850208
# ..                 ...                     ...                       ...
# 112                  0            6.909581e+08             112107.434614
# 113                  9            1.273682e+09             143258.503493
# 114                  2            1.102099e+09             132761.715355
# 115                  0            1.372186e+09             161629.878990
# 116                  1            1.744679e+09             210145.418054
#
#                       attributes.GlobalID  attributes.CreationDate  \
# 0    d8177a93-d492-45c6-bb70-37c7d3a92f58            1599937856332
# 1    ead197b9-c65f-4c79-ae13-08b40e285a74            1599937856734
# 2    5a5643e6-232a-4024-8325-81eaee0462c0            1599937857000
# 3    40f677fc-9333-47fc-9a45-472a55328ed9            1599937857294
# 4    c288aa5f-c5e7-4918-bb9e-d7877b35f52f            1599937857536
# ..                                    ...                      ...
# 112  71811944-1a11-4f32-abb3-1439e43a33c4            1599937883737
# 113  7a1395c6-8073-467a-8892-9aa2f64f4fbb            1599937883872
# 114  d7fec049-9765-4492-9c12-be2302eb9518            1599937883997
# 115  67cd35eb-d1e9-4ef5-a908-e4db9e115ef6            1599937884111
# 116  decec803-a910-44df-868c-6a2dbe5a113b            1599937884231
#
#     attributes.Creator  attributes.EditDate attributes.Editor  \
# 0               mophep        1599937856332            mophep
# 1               mophep        1599937856734            mophep
# 2               mophep        1599937857000            mophep
# 3               mophep        1599937857294            mophep
# 4               mophep        1599937857536            mophep
# ..                 ...                  ...               ...
# 112             mophep        1599937883737            mophep
# 113             mophep        1599937883872            mophep
# 114             mophep        1599937883997            mophep
# 115             mophep        1599937884111            mophep
# 116             mophep        1599937884231            mophep
#
#                                         geometry.rings
# 0    [[[-92.3478208840285, 40.302804629629], [-92.3...
# 1    [[[-94.6059390844084, 40.1261753038853], [-94....
# 2    [[[-95.2024414996767, 40.5784663769025], [-95....
# 3    [[[-91.7179813406387, 39.3391363676128], [-91....
# 4    [[[-93.6110169618323, 36.9228443060673], [-93....
# ..                                                 ...
# 112  [[[-94.2142068454973, 40.3987217696141], [-94....
# 113  [[[-94.5890217181668, 40.3866648099594], [-94....
# 114  [[[-94.2056954453697, 39.8181306353613], [-94....
# 115  [[[-91.8315698656889, 38.2933315698199], [-91....
# 116  [[[-91.5249240237418, 38.1523446245754], [-91....
#
# [117 rows x 13 columns]
