# %%
 # Dependencies
import pandas as pd
import scipy.stats as stats
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests

# %%
fips_data = "mo_county_fips.csv"
fips_data_df = pd.read_csv(fips_data, encoding="ISO-8859-1")
fips_data_df
# Out:
#      ï»¿Summary Level  State Code (FIPS)  County Code (FIPS)  \
# 0                  50                 29                   1
# 1                  50                 29                   3
# 2                  50                 29                   5
# 3                  50                 29                   7
# 4                  50                 29                   9
# ..                ...                ...                 ...
# 110                50                 29                 223
# 111                50                 29                 225
# 112                50                 29                 227
# 113                50                 29                 229
# 114                50                 29                 510
#
#     Area Name (including legal/statistical area description)
# 0                                         Adair County
# 1                                        Andrew County
# 2                                      Atchison County
# ...

# %%
clean_fips_data_df = fips_data_df.iloc[:,1:]
clean_fips_data_df.to_csv("Data_Cleaning/mo_fips.csv", index=False, header=True)

# %%
clean_fips_data_df
# Out:
#      State Code (FIPS)  County Code (FIPS)  \
# 0                   29                   1
# 1                   29                   3
# 2                   29                   5
# 3                   29                   7
# 4                   29                   9
# ..                 ...                 ...
# 110                 29                 223
# 111                 29                 225
# 112                 29                 227
# 113                 29                 229
# 114                 29                 510
#
#     Area Name (including legal/statistical area description)
# 0                                         Adair County
# 1                                        Andrew County
# 2                                      Atchison County
# 3                                       Audrain County
# 4                                         Barry County
# ..                                                 ...
# ...

# %%
clean_fips_data_df.dtypes
# Out:
# State Code (FIPS)                                            int64
# County Code (FIPS)                                           int64
# Area Name (including legal/statistical area description)    object
# dtype: object

# %%
Data_Cleaning/Master_County_Data.csv
county_data = "/Data_Cleaning/Master_County_Data.csv"
county_data_df = pd.read_csv(county_data, encoding="ISO-8859-1")
county_data_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-0d8fd23b18bc> in <module>()
# ----> 1 Data_Cleaning/Master_County_Data.csv
#       2 county_data = "/Data_Cleaning/Master_County_Data.csv"
#       3 county_data_df = pd.read_csv(county_data, encoding="ISO-8859-1")
#       4 county_data_df
#
# NameError: name 'Data_Cleaning' is not defined
