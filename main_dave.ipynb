# %%
 # Dependencies
import pandas as pd
import scipy.stats as stats
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests

# %%
fips_data = "mo_county_fips.csv"
fips_data_df = pd.read_csv(fips_data, encoding="ISO-8859-1")
fips_data_df
# Out:
#      ï»¿Summary Level  State Code (FIPS)  County Code (FIPS)  \
# 0                  50                 29                   1
# 1                  50                 29                   3
# 2                  50                 29                   5
# 3                  50                 29                   7
# 4                  50                 29                   9
# ..                ...                ...                 ...
# 110                50                 29                 223
# 111                50                 29                 225
# 112                50                 29                 227
# 113                50                 29                 229
# 114                50                 29                 510
#
#     Area Name (including legal/statistical area description)
# 0                                         Adair County
# 1                                        Andrew County
# 2                                      Atchison County
# 3                                       Audrain County
# 4                                         Barry County
# ..                                                 ...
# 110                                       Wayne County
# 111                                     Webster County
# 112                                       Worth County
# 113                                      Wright County
# 114                           City of St. Louis County
#
# [115 rows x 4 columns]

# %%
clean_fips_data_df = fips_data_df.iloc[:,1:]
clean_fips_data_df.to_csv("Data_Cleaning/mo_fips.csv", index=False, header=True)

# %%
clean_fips_data_df
# Out:
#      State Code (FIPS)  County Code (FIPS)  \
# 0                   29                   1
# 1                   29                   3
# 2                   29                   5
# 3                   29                   7
# 4                   29                   9
# ..                 ...                 ...
# 110                 29                 223
# 111                 29                 225
# 112                 29                 227
# 113                 29                 229
# 114                 29                 510
#
#     Area Name (including legal/statistical area description)
# 0                                         Adair County
# 1                                        Andrew County
# 2                                      Atchison County
# 3                                       Audrain County
# 4                                         Barry County
# ..                                                 ...
# 110                                       Wayne County
# 111                                     Webster County
# 112                                       Worth County
# 113                                      Wright County
# 114                           City of St. Louis County
#
# [115 rows x 3 columns]

# %%
clean_fips_data_df.dtypes
# Out:
# State Code (FIPS)                                            int64
# County Code (FIPS)                                           int64
# Area Name (including legal/statistical area description)    object
# dtype: object

# %%
county_data = "Data_Cleaning/Master_County_Data.csv"
county_data_df = pd.read_csv(county_data, encoding="ISO-8859-1")
county_data_df
# Out:
#              dt  location   fips  cases_total  deaths_total  \
# 0    2020-09-15     29001  29001        315.0           0.0
# 1    2020-09-15     29003  29003        189.0           1.0
# 2    2020-09-15     29005  29005         41.0           0.0
# 3    2020-09-15     29007  29007        372.0           2.0
# 4    2020-09-15     29009  29009        411.0           5.0
# ..          ...       ...    ...          ...           ...
# 110  2020-09-15     29223  29223        152.0           0.0
# 111  2020-09-15     29225  29225        427.0           2.0
# 112  2020-09-15     29227  29227         18.0           0.0
# 113  2020-09-15     29229  29229        165.0           0.0
# 114  2020-09-15     29510  29510       6667.0         196.0
#
#      hospital_beds_capacity_count  hospital_beds_in_use_any  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
# ..                            ...                       ...
# 110                           NaN                       NaN
# 111                           NaN                       NaN
# 112                           NaN                       NaN
# 113                           NaN                       NaN
# 114                           NaN                       NaN
#
#      hospital_beds_in_use_covid_total  icu_beds_capacity_count  \
# 0                                 NaN                      NaN
# 1                                 NaN                      NaN
# 2                                 NaN                      NaN
# 3                                 NaN                      NaN
# 4                                 NaN                      NaN
# ..                                ...                      ...
# 110                               NaN                      NaN
# 111                               NaN                      NaN
# 112                               NaN                      NaN
# 113                               NaN                      NaN
# 114                               NaN                      NaN
#
#      icu_beds_in_use_any  ...  Percent of 25+ with professional degree  \
# 0                    NaN  ...                                     15.0
# 1                    NaN  ...                                      8.0
# 2                    NaN  ...                                      6.0
# 3                    NaN  ...                                      5.0
# 4                    NaN  ...                                      4.0
# ..                   ...  ...                                      ...
# 110                  NaN  ...                                      3.0
# 111                  NaN  ...                                      6.0
# 112                  NaN  ...                                      5.0
# 113                  NaN  ...                                      4.0
# 114                  NaN  ...                                     15.6
#
#      Percent of 25+ with some HS but no HS degree  \
# 0                                            6.00
# 1                                            5.00
# 2                                            6.00
# 3                                           10.00
# 4                                           11.00
# ..                                            ...
# 110                                         16.00
# 111                                          7.00
# 112                                          7.00
# 113                                         10.00
# 114                                          8.75
#
#      Percent of 25+ with some college but no degree  \
# 0                                             17.00
# 1                                             22.00
# 2                                             21.00
# 3                                             17.00
# 4                                             20.00
# ..                                              ...
# 110                                           21.00
# 111                                           24.00
# 112                                           22.00
# 113                                           18.00
# 114                                           21.25
#
#      Percent of civilian population with health insurance  \
# 0                                                 91.0
# 1                                                 92.0
# 2                                                 91.0
# 3                                                 90.0
# 4                                                 84.0
# ..                                                 ...
# 110                                               85.0
# 111                                               84.0
# 112                                               93.0
# 113                                               81.0
# 114                                               88.8
#
#      Percent of civilian population with no health insurance  \
# 0                                                  8.0
# 1                                                  7.0
# 2                                                  8.0
# 3                                                 10.0
# 4                                                 15.0
# ..                                                 ...
# 110                                               14.0
# 111                                               15.0
# 112                                                6.0
# 113                                               18.0
# 114                                               10.7
#
#     Percent of families w/ income < poverty lvl in last year  \
# 0                                                 11.0
# 1                                                  6.0
# 2                                                  6.0
# 3                                                 10.0
# 4                                                 14.0
# ..                                                 ...
# 110                                               15.0
# 111                                               12.0
# 112                                                8.0
# 113                                               19.0
# 114                                               17.5
#
#     Percent other race  Percent two or more races  Percent white  \
# 0                 0.00                       2.00          91.00
# 1                 0.00                       1.00          95.00
# 2                 0.00                       0.00          97.00
# 3                 0.00                       3.00          89.00
# 4                 1.00                       3.00          93.00
# ..                 ...                        ...            ...
# 110               0.00                       2.00          96.00
# 111               0.00                       1.00          95.00
# 112               0.00                       2.00          97.00
# 113               1.00                       1.00          96.00
# 114               0.95                       2.35          46.55
#
#      Total population
# 0             25325.0
# 1             17403.0
# 2              5270.0
# 3             25735.0
# 4             35493.0
# ..                ...
# 110           13308.0
# 111           38082.0
# 112            2040.0
# 113           18293.0
# 114          307055.5
#
# [115 rows x 52 columns]
